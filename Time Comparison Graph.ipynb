# %%
import matplotlib.pyplot as plt

# Data for the bar graph
models = ['CPU Nano 10E', 'GPU Nano 10E', 'GPU Small 30E']
run_times = [5.43, 0.37, 1.49]  # Replace with the actual run times (e.g., in seconds)
colors = ['skyblue', 'salmon', 'palegreen']   # Colors for the bars

# Create the bar graph
plt.figure(figsize=(8, 6))
plt.bar(models, run_times, width=0.5, color=colors)

# Adding titles and labels
plt.title('Comparison of Model Run Times', fontsize=16)
plt.xlabel('Machine Learning Models', fontsize=12)
plt.ylabel('Run Time (Hours)', fontsize=12)

# Adding values on top of the bars
for i, v in enumerate(run_times):
    plt.text(i, v+0.05, str(v), ha='center', fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()
